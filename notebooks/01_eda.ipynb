# %% [markdown]
# # Telco churn — EDA
#
# Reproducible CLI from repo root: `python -m churn_ml.eda.run -i path/to.csv`. This notebook runs the same pipeline interactively (install the package in editable mode first: `pip install -e .` from repo root).

# %%
from pathlib import Path

from churn_ml.eda.summary import run_eda_pipeline

ROOT = Path("..").resolve()
CSV = ROOT / "tests" / "fixtures" / "telco_sample.csv"
OUT = ROOT / "reports"

paths = run_eda_pipeline(CSV, OUT, skip_validation=False)
paths
